# %%
import json
import requests

# %%
rennes = requests.get('https://data.rennesmetropole.fr/api/records/1.0/search/?dataset=etat-des-stations-le-velo-star-en-temps-reel')
rennes = rennes.json()
rennes
# Out:
# {'nhits': 58,
#  'parameters': {'dataset': ['etat-des-stations-le-velo-star-en-temps-reel'],
#   'rows': 10,
#   'start': 0,
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '88a8871cd455b991aae541e2d60ebdab34840e3e',
#    'fields': {'nombrevelosdisponibles': 9,
#     'nombreemplacementsdisponibles': 7,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsactuels': 16,
#     'idstation': '5510',
#     'etat': 'En panne',
#     'coordonnees': [48.109601, -1.67408],
#     'lastupdate': '2022-03-25T21:16:08+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [-1.67408, 48.109601]},
#    'record_timestamp': '2022-03-25T21:16:00Z'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb',
#    'fields': {'nombrevelosdisponibles': 5,
#     'nombreemplacementsdisponibles': 18,
#     'nom': 'Plaine de Baud',
# ...

# %%
for i in range(len(rennes['records'])):
    rennes['records'][i]['fields']['lat']=rennes['records'][i]['fields']['coordonnees'][0]
    rennes['records'][i]['fields']['lon']=rennes['records'][i]['fields']['coordonnees'][1]
    del rennes['records'][i]['fields']['coordonnees']
    
rennes
# Out:
# {'nhits': 58,
#  'parameters': {'dataset': ['etat-des-stations-le-velo-star-en-temps-reel'],
#   'rows': 10,
#   'start': 0,
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '88a8871cd455b991aae541e2d60ebdab34840e3e',
#    'fields': {'nombrevelosdisponibles': 9,
#     'nombreemplacementsdisponibles': 7,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsactuels': 16,
#     'idstation': '5510',
#     'etat': 'En fonctionnement',
#     'lastupdate': '2022-03-24T17:39:06+00:00',
#     'lat': 48.109601,
#     'lon': -1.67408},
#    'geometry': {'type': 'Point', 'coordinates': [-1.67408, 48.109601]},
#    'record_timestamp': '2022-03-24T17:39:00Z'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb',
#    'fields': {'nombrevelosdisponibles': 3,
#     'nombreemplacementsdisponibles': 21,
#     'nom': 'Plaine de Baud',
# ...

# %%
rennes
# Out:
# {'nhits': 58,
#  'parameters': {'dataset': ['etat-des-stations-le-velo-star-en-temps-reel'],
#   'rows': 10,
#   'start': 0,
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '88a8871cd455b991aae541e2d60ebdab34840e3e',
#    'fields': {'nombrevelosdisponibles': 9,
#     'nombreemplacementsdisponibles': 7,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsactuels': 16,
#     'idstation': '5510',
#     'etat': 'En fonctionnement',
#     'lastupdate': '2022-03-24T17:39:06+00:00',
#     'lat': 48.109601,
#     'lon': -1.67408},
#    'geometry': {'type': 'Point', 'coordinates': [-1.67408, 48.109601]},
#    'record_timestamp': '2022-03-24T17:39:00Z'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb',
#    'fields': {'nombrevelosdisponibles': 3,
#     'nombreemplacementsdisponibles': 21,
#     'nom': 'Plaine de Baud',
# ...

# %%
contextRennes = { "@context": { "@vocab": "http://www.owl-ontologies.com/unnamed.owl",
                                "@base": "http://www.owl-ontologies.com/unnamed.owl",
                                "xsd": "http://www.w3.org/2001/XMLSchema#",


                                "datasetid": null,
                                "recordid": null,
                                "nombrevelosdisponibles": null,
                                "nombreemplacementsdisponibles": {
                                    "@id":"available_place",
                                    "@type":"xsd:float"
                                },
                                "nom": {
                                  "@id":"Name",
                                  "@type":"xsd:string"
                                },
                                "nombreemplacementsactuels": {
                                  "@id":"capacity",
                                  "@type":"xsd:int"
                                },
                                "idstation":{
                                  "@id":"id",
                                  "@type":"xsd:string"
                                },
                                "etat": {
                                  "@id":"status",
                                  "@type":"xsd:strin"
                                },
                                "lastupdate": null,
                                "lat": {
                                  "@id":"latitude",
                                  "@type":"xsd:float"
                                },
                                "lon": {
                                  "@id":"longiude",
                                  "@type":"xsd:float"
                                },
                                "type": null, 
                                "coordinates": null,
                                "record_timestamp": null
                            }

                        }

# %%
strasbourg = {
  "vcs": {
    "-ver": "1",
    "sl": {
      "si": [
        {
          "-na": "124 Auberge de jeunesse",
          "-id": "124",
          "-la": "48.568644",
          "-lg": "7.795621",
          "-av": "6",
          "-fr": "10",
          "-to": "16",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "111 Campus d'Illkirch",
          "-id": "111",
          "-la": "48.529616",
          "-lg": "7.734226",
          "-av": "5",
          "-fr": "25",
          "-to": "30",
          "-self-closing": "true"
        },
        {
          "-na": "101 Centre",
          "-id": "101",
          "-la": "48.578462",
          "-lg": "7.749776",
          "-av": "22",
          "-fr": "10",
          "-to": "32",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "102 Centre 2",
          "-id": "102",
          "-la": "48.578462",
          "-lg": "7.749776",
          "-av": "1",
          "-fr": "19",
          "-to": "20",
          "-self-closing": "true"
        },
        {
          "-na": "126 Espace Européen de l'Entreprise",
          "-id": "126",
          "-la": "48.612597",
          "-lg": "7.711630",
          "-av": "8",
          "-fr": "8",
          "-to": "16",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "103 Gare de Strasbourg",
          "-id": "103",
          "-la": "48.585082",
          "-lg": "7.735024",
          "-av": "10",
          "-fr": "21",
          "-to": "31",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "115 Hoenheim Gare",
          "-id": "115",
          "-la": "48.628353",
          "-lg": "7.760103",
          "-av": "12",
          "-fr": "4",
          "-to": "16",
          "-self-closing": "true"
        },
        {
          "-na": "112 Hohwart",
          "-id": "112",
          "-la": "48.549190",
          "-lg": "7.740754",
          "-av": "7",
          "-fr": "3",
          "-to": "10",
          "-self-closing": "true"
        },
        {
          "-na": "123 Koenigshoffen",
          "-id": "123",
          "-la": "48.579100",
          "-lg": "7.713481",
          "-av": "7",
          "-fr": "19",
          "-to": "26",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "127 Ostwald Hôtel de Ville",
          "-id": "127",
          "-la": "48.551032",
          "-lg": "7.711200",
          "-av": "5",
          "-fr": "11",
          "-to": "16",
          "-self-closing": "true"
        },
        {
          "-na": "114 Parking Austerlitz",
          "-id": "114",
          "-la": "48.578005",
          "-lg": "7.751863",
          "-av": "9",
          "-fr": "21",
          "-to": "30",
          "-self-closing": "true"
        },
        {
          "-na": "113 Parking Broglie",
          "-id": "113",
          "-la": "48.585415",
          "-lg": "7.749395",
          "-av": "14",
          "-fr": "16",
          "-to": "30",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "109 Place Arnold",
          "-id": "109",
          "-la": "48.584504",
          "-lg": "7.768772",
          "-av": "10",
          "-fr": "18",
          "-to": "28",
          "-self-closing": "true"
        },
        {
          "-na": "108 Gare Nord",
          "-id": "108",
          "-la": "48.585678",
          "-lg": "7.733542",
          "-av": "5",
          "-fr": "27",
          "-to": "32",
          "-self-closing": "true"
        },
        {
          "-na": "106 Gare Sud",
          "-id": "106",
          "-la": "48.584209",
          "-lg": "7.734519",
          "-av": "21",
          "-fr": "11",
          "-to": "32",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "116 Place Islande",
          "-id": "116",
          "-la": "48.580314",
          "-lg": "7.776203",
          "-av": "9",
          "-fr": "7",
          "-to": "16",
          "-self-closing": "true"
        },
        {
          "-na": "125 Place du Marché Neudorf",
          "-id": "125",
          "-la": "48.565864",
          "-lg": "7.759242",
          "-av": "13",
          "-fr": "19",
          "-to": "32",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "110 Robertsau Boecklin",
          "-id": "110",
          "-la": "48.598096",
          "-lg": "7.777902",
          "-av": "7",
          "-fr": "25",
          "-to": "32",
          "-self-closing": "true"
        },
        {
          "-na": "105 Rotonde",
          "-id": "105",
          "-la": "48.591639",
          "-lg": "7.725089",
          "-av": "8",
          "-fr": "24",
          "-to": "32",
          "-self-closing": "true"
        },
        {
          "-na": "122 Schiltigheim Mairie",
          "-id": "122",
          "-la": "48.606759",
          "-lg": "7.749183",
          "-av": "7",
          "-fr": "9",
          "-to": "16",
          "-cb": "1",
          "-self-closing": "true"
        },
        {
          "-na": "107 Université",
          "-id": "107",
          "-la": "48.582023",
          "-lg": "7.766771",
          "-av": "8",
          "-fr": "24",
          "-to": "32",
          "-cb": "1",
          "-self-closing": "true"
        }
      ]
    }
  },
  "#omit-xml-declaration": "yes"
}

# %%
strasbourg = {"vcs": {"-ver": "1",
    "sl": {"si": [{"-na": "124 Auberge de jeunesse",
       "-id": "124",
       "-la": "48.568644",
       "-lg": "7.795621",
       "-av": "6",
       "-fr": "10",
       "-to": "16",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "111 Campus d'Illkirch",
       "-id": "111",
       "-la": "48.529616",
       "-lg": "7.734226",
       "-av": "5",
       "-fr": "25",
       "-to": "30",
       "-self-closing": "true"},
      {"-na": "101 Centre",
       "-id": "101",
       "-la": "48.578462",
       "-lg": "7.749776",
       "-av": "22",
       "-fr": "10",
       "-to": "32",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "102 Centre 2",
       "-id": "102",
       "-la": "48.578462",
       "-lg": "7.749776",
       "-av": "1",
       "-fr": "19",
       "-to": "20",
       "-self-closing": "true"},
      {"-na": "126 Espace Européen de l'Entreprise",
       "-id": "126",
       "-la": "48.612597",
       "-lg": "7.711630",
       "-av": "8",
       "-fr": "8",
       "-to": "16",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "103 Gare de Strasbourg",
       "-id": "103",
       "-la": "48.585082",
       "-lg": "7.735024",
       "-av": "10",
       "-fr": "21",
       "-to": "31",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "115 Hoenheim Gare",
       "-id": "115",
       "-la": "48.628353",
       "-lg": "7.760103",
       "-av": "12",
       "-fr": "4",
       "-to": "16",
       "-self-closing": "true"},
      {"-na": "112 Hohwart",
       "-id": "112",
       "-la": "48.549190",
       "-lg": "7.740754",
       "-av": "7",
       "-fr": "3",
       "-to": "10",
       "-self-closing": "true"},
      {"-na": "123 Koenigshoffen",
       "-id": "123",
       "-la": "48.579100",
       "-lg": "7.713481",
       "-av": "7",
       "-fr": "19",
       "-to": "26",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "127 Ostwald Hôtel de Ville",
       "-id": "127",
       "-la": "48.551032",
       "-lg": "7.711200",
       "-av": "5",
       "-fr": "11",
       "-to": "16",
       "-self-closing": "true"},
      {"-na": "114 Parking Austerlitz",
       "-id": "114",
       "-la": "48.578005",
       "-lg": "7.751863",
       "-av": "9",
       "-fr": "21",
       "-to": "30",
       "-self-closing": "true"},
      {"-na": "113 Parking Broglie",
       "-id": "113",
       "-la": "48.585415",
       "-lg": "7.749395",
       "-av": "14",
       "-fr": "16",
       "-to": "30",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "109 Place Arnold",
       "-id": "109",
       "-la": "48.584504",
       "-lg": "7.768772",
       "-av": "10",
       "-fr": "18",
       "-to": "28",
       "-self-closing": "true"},
      {"-na": "108 Gare Nord",
       "-id": "108",
       "-la": "48.585678",
       "-lg": "7.733542",
       "-av": "5",
       "-fr": "27",
       "-to": "32",
       "-self-closing": "true"},
      {"-na": "106 Gare Sud",
       "-id": "106",
       "-la": "48.584209",
       "-lg": "7.734519",
       "-av": "21",
       "-fr": "11",
       "-to": "32",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "116 Place Islande",
       "-id": "116",
       "-la": "48.580314",
       "-lg": "7.776203",
       "-av": "9",
       "-fr": "7",
       "-to": "16",
       "-self-closing": "true"},
      {"-na": "125 Place du Marché Neudorf",
       "-id": "125",
       "-la": "48.565864",
       "-lg": "7.759242",
       "-av": "13",
       "-fr": "19",
       "-to": "32",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "110 Robertsau Boecklin",
       "-id": "110",
       "-la": "48.598096",
       "-lg": "7.777902",
       "-av": "7",
       "-fr": "25",
       "-to": "32",
       "-self-closing": "true"},
      {"-na": "105 Rotonde",
       "-id": "105",
       "-la": "48.591639",
       "-lg": "7.725089",
       "-av": "8",
       "-fr": "24",
       "-to": "32",
       "-self-closing": "true"},
      {"-na": "122 Schiltigheim Mairie",
       "-id": "122",
       "-la": "48.606759",
       "-lg": "7.749183",
       "-av": "7",
       "-fr": "9",
       "-to": "16",
       "-cb": "1",
       "-self-closing": "true"},
      {"-na": "107 Université",
       "-id": "107",
       "-la": "48.582023",
       "-lg": "7.766771",
       "-av": "8",
       "-fr": "24",
       "-to": "32",
       "-cb": "1",
       "-self-closing": "true"}]}},
   "#omit-xml-declaration": "yes"}

strasbourg = strasbourg['vcs']['sl']['si']

# %%
tmp = []
for i in range(len(strasbourg)):
    tmp.append({'name': strasbourg[i]['-na'],
    'lat':strasbourg[i]['-la'],
    'lon':strasbourg[i]['-lg'],
    'available_place':strasbourg[i]['-av']})

# %%
tmp
# Out:
# [{'name': '124 Auberge de jeunesse',
#   'lat': '48.568644',
#   'lon': '7.795621',
#   'available_place': '6'},
#  {'name': "111 Campus d'Illkirch",
#   'lat': '48.529616',
#   'lon': '7.734226',
#   'available_place': '5'},
#  {'name': '101 Centre',
#   'lat': '48.578462',
#   'lon': '7.749776',
#   'available_place': '22'},
#  {'name': '102 Centre 2',
#   'lat': '48.578462',
#   'lon': '7.749776',
#   'available_place': '1'},
#  {'name': "126 Espace Européen de l'Entreprise",
#   'lat': '48.612597',
#   'lon': '7.711630',
#   'available_place': '8'},
#  {'name': '103 Gare de Strasbourg',
#   'lat': '48.585082',
#   'lon': '7.735024',
#   'available_place': '10'},
#  {'name': '115 Hoenheim Gare',
#   'lat': '48.628353',
#   'lon': '7.760103',
#   'available_place': '12'},
#  {'name': '112 Hohwart',
#   'lat': '48.549190',
#   'lon': '7.740754',
#   'available_place': '7'},
#  {'name': '123 Koenigshoffen',
#   'lat': '48.579100',
#   'lon': '7.713481',
#   'available_place': '7'},
# ...

# %%
rennes = requests.get('https://data.rennesmetropole.fr/api/records/1.0/search/?dataset=etat-des-stations-le-velo-star-en-temps-reel')
rennes = rennes.json()
rennes = rennes['records']
for i in range(len(rennes)):
    del rennes[i]['recordid']
    del rennes[i]['datasetid']
    del rennes[i]['geometry']
    del rennes[i]['record_timestamp']
    rennes[i] = rennes[i]['fields']
for i in range(len(rennes)):
    del rennes[i]['nombrevelosdisponibles']
    del rennes[i]['nombreemplacementsactuels']
    del rennes[i]['idstation']
    del rennes[i]['lastupdate']
    del rennes[i]['etat']

# %%
rennes
# Out:
# [{'nombreemplacementsdisponibles': 5,
#   'nom': 'Musée Beaux-Arts',
#   'coordonnees': [48.109601, -1.67408]},
#  {'nombreemplacementsdisponibles': 23,
#   'nom': 'Plaine de Baud',
#   'coordonnees': [48.112461, -1.643674]},
#  {'nombreemplacementsdisponibles': 8,
#   'nom': 'Brest - Verdun',
#   'coordonnees': [48.113009, -1.693264]},
#  {'nombreemplacementsdisponibles': 6,
#   'nom': 'Marbeuf',
#   'coordonnees': [48.111749, -1.702077]},
#  {'nombreemplacementsdisponibles': 10,
#   'nom': 'Gros-Chêne',
#   'coordonnees': [48.125408, -1.664806]},
#  {'nombreemplacementsdisponibles': 25,
#   'nom': 'Painlevé',
#   'coordonnees': [48.123506, -1.659762]},
#  {'nombreemplacementsdisponibles': 30,
#   'nom': 'Joliot-Curie - Chateaubriand',
#   'coordonnees': [48.124389, -1.651203]},
#  {'nombreemplacementsdisponibles': 1,
#   'nom': 'Pont de Strasbourg',
#   'coordonnees': [48.109859, -1.656028]},
#  {'nombreemplacementsdisponibles': 9,
#   'nom': 'Mabilais',
# ...

# %%
lyon = requests.get("https://download.data.grandlyon.com/wfs/rdata?SERVICE=WFS&VERSION=1.1.0&outputformat=GEOJSON&request=GetFeature&typename=jcd_jcdecaux.jcdvelov&SRSNAME=urn:ogc:def:crs:EPSG::4171")
lyon = lyon.json()
lyon = lyon['features']
tmp = []
for i in range(len(lyon)):
    tmp.append({'name' : lyon[i]['properties']['name'], 
    'available_place':lyon[i]['properties']['available_bike_stands'], 
    'lat' : float(lyon[i]['properties']['lat']), 
    'lng' : float(lyon[i]['properties']['lng'])})

# %%
tmp
# Out:
# [{'name': 'Vénissieux - Place Romand',
#   'available_place': '6',
#   'lat': 45.725754727114285,
#   'lng': 4.858350997738892},
#  {'name': 'Chazière',
#   'available_place': '13',
#   'lat': 45.77542246689847,
#   'lng': 4.8178899295525035},
#  {'name': 'Charles Hernu',
#   'available_place': '10',
#   'lat': 45.770310528129194,
#   'lng': 4.862002498921167},
#  {'name': 'Place Crépu',
#   'available_place': '6',
#   'lat': 45.75784167963824,
#   'lng': 4.826105451692288},
#  {'name': 'Delore / Audibert & Lavirotte',
#   'available_place': '6',
#   'lat': 45.73579523205929,
#   'lng': 4.8568128186712},
#  {'name': 'Villeurbanne Saint-Jean',
#   'available_place': '8',
#   'lat': 45.78044582171094,
#   'lng': 4.904488845789296},
#  {'name': 'Bron - Centre Nautique',
#   'available_place': '7',
#   'lat': 45.742924838354064,
#   'lng': 4.908621338411986},
#  {'name': 'Jean Jaurès',
#   'available_place': '4',
#   'lat': 45.737518097350936,
#   'lng': 4.837508919917021},
# ...

# %%
lyon = requests.get("https://download.data.grandlyon.com/wfs/rdata?SERVICE=WFS&VERSION=1.1.0&outputformat=GEOJSON&request=GetFeature&typename=jcd_jcdecaux.jcdvelov&SRSNAME=urn:ogc:def:crs:EPSG::4171")
lyon = lyon.json()
lyon = lyon['features']
tmp = []
for i in range(len(lyon)):
    tmp.append({'name' : lyon[i]['properties']['name'], 
                'available_place':lyon[i]['properties']['available_bike_stands'],
               'lat' : lyon[i]['properties']['lat'],
              'lng' : lyon[i]['properties']['lng']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q5/zd2qdf_n46d548x8r2m59q_r0000gn/T/ipykernel_9210/1847105706.py in <module>
# ----> 1 lyon = requests.get("https://download.data.grandlyon.com/wfs/rdata?SERVICE=WFS&VERSION=1.1.0&outputformat=GEOJSON&request=GetFeature&typename=jcd_jcdecaux.jcdvelov&SRSNAME=urn:ogc:def:crs:EPSG::4171")
#       2 lyon = lyon.json()
#       3 lyon = lyon['features']
#       4 tmp = []
#       5 for i in range(len(lyon)):
#
# NameError: name 'requests' is not defined

# %%
tmp
# Out:
# [{'name': 'Gratte-Ciel',
#   'available_place': '4',
#   'lat': '45.7692274364669060',
#   'lng': '4.8804622522382600'},
#  {'name': 'Etats-Unis / Lévigne',
#   'available_place': '9',
#   'lat': '45.7322180106596860',
#   'lng': '4.8651415367367150'},
#  {'name': 'Croix Rousse / Perfetti',
#   'available_place': '20',
#   'lat': '45.7722538415304900',
#   'lng': '4.8194608620100040'},
#  {'name': 'Gambetta / Garibaldi',
#   'available_place': '8',
#   'lat': '45.7517901355474700',
#   'lng': '4.8526079660087520'},
#  {'name': 'Quartier Général Frère',
#   'available_place': '20',
#   'lat': '45.7431645419377450',
#   'lng': '4.8341688750746420'},
#  {'name': 'Cité Internationale - Résidence hôtelière',
#   'available_place': '28',
#   'lat': '45.7848181552653900',
#   'lng': '4.8565116142349005'},
#  {'name': 'Célestins',
#   'available_place': '5',
#   'lat': '45.7599398325897200',
#   'lng': '4.8320716113863760'},
#  {'name': 'Place du Château',
#   'available_place': '16',
# ...

# %%
montpellier = {
    "vcs": {
      "-ver": "1",
      "sl": {
        "si": [
          {
            "-na": "001 Rue Jules Ferry - Gare Saint-Roch",
            "-id": "001",
            "-la": "43.605366",
            "-lg": "3.881346",
            "-av": "1",
            "-fr": "11",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "002 Comédie",
            "-id": "002",
            "-la": "43.608148",
            "-lg": "3.878778",
            "-av": "18",
            "-fr": "6",
            "-to": "24",
            "-self-closing": "true"
          },
          {
            "-na": "003 Esplanade",
            "-id": "003",
            "-la": "43.609478",
            "-lg": "3.881293",
            "-av": "8",
            "-fr": "24",
            "-to": "32",
            "-self-closing": "true"
          },
          {
            "-na": "004 Hôtel de Ville",
            "-id": "004",
            "-la": "43.599088",
            "-lg": "3.894866",
            "-av": "12",
            "-fr": "4",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "005 Corum",
            "-id": "005",
            "-la": "43.613989",
            "-lg": "3.881600",
            "-av": "10",
            "-fr": "2",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "006 Place Albert 1er - St Charles",
            "-id": "006",
            "-la": "43.616768",
            "-lg": "3.873375",
            "-av": "19",
            "-fr": "12",
            "-to": "31",
            "-self-closing": "true"
          },
          {
            "-na": "007 Foch",
            "-id": "007",
            "-la": "43.610989",
            "-lg": "3.873345",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "008 Halles Castellane",
            "-id": "008",
            "-la": "43.609935",
            "-lg": "3.877208",
            "-av": "3",
            "-fr": "9",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "009 Observatoire",
            "-id": "009",
            "-la": "43.606081",
            "-lg": "3.876931",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "010 Rondelet",
            "-id": "010",
            "-la": "43.603038",
            "-lg": "3.875796",
            "-av": "2",
            "-fr": "14",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "011 Plan Cabanes",
            "-id": "011",
            "-la": "43.608491",
            "-lg": "3.868389",
            "-av": "1",
            "-fr": "11",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "012 Boutonnet",
            "-id": "012",
            "-la": "43.622629",
            "-lg": "3.868375",
            "-av": "2",
            "-fr": "10",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "013 Emile Combes",
            "-id": "013",
            "-la": "43.616742",
            "-lg": "3.87998",
            "-av": "3",
            "-fr": "5",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "014 Beaux-Arts",
            "-id": "014",
            "-la": "43.616698",
            "-lg": "3.884981",
            "-av": "4",
            "-fr": "4",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "015 Les Aubes",
            "-id": "015",
            "-la": "43.618692",
            "-lg": "3.893844",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "016 Antigone centre",
            "-id": "016",
            "-la": "43.607942",
            "-lg": "3.890634",
            "-av": "11",
            "-fr": "5",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "017 Médiathèque Emile Zola",
            "-id": "017",
            "-la": "43.608218",
            "-lg": "3.893140",
            "-av": "7",
            "-fr": "9",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "018 Nombre d'Or",
            "-id": "018",
            "-la": "43.607859",
            "-lg": "3.886644",
            "-av": "6",
            "-fr": "10",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "019 Louis Blanc",
            "-id": "019",
            "-la": "43.614642",
            "-lg": "3.877648",
            "-av": "15",
            "-fr": "1",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "020 Gambetta",
            "-id": "020",
            "-la": "43.607106",
            "-lg": "3.870693",
            "-av": "0",
            "-fr": "8",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "021 Port Marianne",
            "-id": "021",
            "-la": "43.600320",
            "-lg": "3.898510",
            "-av": "16",
            "-fr": "0",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "022 Clemenceau",
            "-id": "022",
            "-la": "43.603539",
            "-lg": "3.872394",
            "-av": "7",
            "-fr": "5",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "023 Les Arceaux",
            "-id": "023",
            "-la": "43.611991",
            "-lg": "3.867157",
            "-av": "8",
            "-fr": "8",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "024 Cité Mion",
            "-id": "024",
            "-la": "43.601143",
            "-lg": "3.884373",
            "-av": "2",
            "-fr": "6",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "025 Nouveau Saint-Roch",
            "-id": "025",
            "-la": "43.599817",
            "-lg": "3.875757",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "026 Renouvier",
            "-id": "026",
            "-la": "43.603553",
            "-lg": "3.867884",
            "-av": "6",
            "-fr": "2",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "027 Odysseum",
            "-id": "027",
            "-la": "43.603727",
            "-lg": "3.918979",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "028 Saint-Denis",
            "-id": "028",
            "-la": "43.605021",
            "-lg": "3.875065",
            "-av": "3",
            "-fr": "5",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "029 Richter",
            "-id": "029",
            "-la": "43.603424",
            "-lg": "3.899263",
            "-av": "16",
            "-fr": "0",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "030 Charles Flahault",
            "-id": "030",
            "-la": "43.618762",
            "-lg": "3.865971",
            "-av": "2",
            "-fr": "6",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "031 Voltaire",
            "-id": "031",
            "-la": "43.603767",
            "-lg": "3.888659",
            "-av": "6",
            "-fr": "2",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "032 Prés d'Arènes",
            "-id": "032",
            "-la": "43.590480",
            "-lg": "3.884611",
            "-av": "4",
            "-fr": "4",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "033 Garcia Lorca",
            "-id": "033",
            "-la": "43.590757",
            "-lg": "3.890616",
            "-av": "8",
            "-fr": "0",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "034 Vert Bois",
            "-id": "034",
            "-la": "43.634580",
            "-lg": "3.868230",
            "-av": "0",
            "-fr": "16",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "035 Malbosc",
            "-id": "035",
            "-la": "43.633679",
            "-lg": "3.832861",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "036 Occitanie",
            "-id": "036",
            "-la": "43.634242",
            "-lg": "3.849128",
            "-av": "1",
            "-fr": "31",
            "-to": "32",
            "-self-closing": "true"
          },
          {
            "-na": "037 FacdesSciences",
            "-id": "037",
            "-la": "43.631018",
            "-lg": "3.860697",
            "-av": "0",
            "-fr": "24",
            "-to": "24",
            "-self-closing": "true"
          },
          {
            "-na": "038 Fac de Lettres",
            "-id": "038",
            "-la": "43.630665",
            "-lg": "3.870230",
            "-av": "0",
            "-fr": "16",
            "-to": "16",
            "-self-closing": "true"
          },
          {
            "-na": "039 Aiguelongue",
            "-id": "039",
            "-la": "43.626163",
            "-lg": "3.882492",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "040 Jeu de Mail des Abbés",
            "-id": "040",
            "-la": "43.619701",
            "-lg": "3.883831",
            "-av": "0",
            "-fr": "8",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "041 Euromédecine",
            "-id": "041",
            "-la": "43.639119",
            "-lg": "3.828199",
            "-av": "0",
            "-fr": "8",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "042 Marie Caizergues",
            "-id": "042",
            "-la": "43.619871",
            "-lg": "3.873812",
            "-av": "4",
            "-fr": "4",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "043 Sabines",
            "-id": "043",
            "-la": "43.584211",
            "-lg": "3.860031",
            "-av": "6",
            "-fr": "2",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "044 Celleneuve",
            "-id": "044",
            "-la": "43.614670",
            "-lg": "3.832624",
            "-av": "3",
            "-fr": "5",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "045 Jardin de la Lironde",
            "-id": "045",
            "-la": "43.605850",
            "-lg": "3.911576",
            "-av": "2",
            "-fr": "6",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "046 Père Soulas",
            "-id": "046",
            "-la": "43.621983",
            "-lg": "3.855603",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "047 Place Viala",
            "-id": "047",
            "-la": "43.616812",
            "-lg": "3.855075",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "048 Hôtel du Département",
            "-id": "048",
            "-la": "43.621682",
            "-lg": "3.834770",
            "-av": "0",
            "-fr": "8",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "049 Tonnelles",
            "-id": "049",
            "-la": "43.615155",
            "-lg": "3.839466",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "050 Parvis Jules Ferry - Gare Saint-Roch",
            "-id": "050",
            "-la": "43.603889",
            "-lg": "3.879362",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "051 Pont de Lattes - Gare Saint-Roch",
            "-id": "051",
            "-la": "43.606036",
            "-lg": "3.882393",
            "-av": "2",
            "-fr": "10",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "053 Deux Ponts - Gare Saint-Roch",
            "-id": "053",
            "-la": "43.604319",
            "-lg": "3.880916",
            "-av": "3",
            "-fr": "5",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "054 Providence - Ovalie",
            "-id": "054",
            "-la": "43.588239",
            "-lg": "3.853421",
            "-av": "2",
            "-fr": "6",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "055 Pérols Etang de l'Or",
            "-id": "055",
            "-la": "43.558351",
            "-lg": "3.963412",
            "-av": "31",
            "-fr": "37",
            "-to": "68",
            "-self-closing": "true"
          },
          {
            "-na": "056 Albert 1er - Cathédrale",
            "-id": "056",
            "-la": "43.614005",
            "-lg": "3.873218",
            "-av": "2",
            "-fr": "10",
            "-to": "12",
            "-self-closing": "true"
          },
          {
            "-na": "057 Saint-Guilhem - Courreau",
            "-id": "057",
            "-la": "43.608996",
            "-lg": "3.872752",
            "-av": "5",
            "-fr": "3",
            "-to": "8",
            "-self-closing": "true"
          },
          {
            "-na": "059 Sud De France",
            "-id": "059",
            "-la": "43.595620",
            "-lg": "3.923500",
            "-av": "1",
            "-fr": "7",
            "-to": "8",
            "-self-closing": "true"
          }
        ]
      }
    },
    "#omit-xml-declaration": "yes"
  }
tmp = []
montpellier = montpellier['vcs']['sl']['si']
for i in range(len(montpellier)):
    tmp.append({'name': montpellier[i]['-na'],
    'lat':montpellier[i]['-la'],
    'lon':montpellier[i]['-lg'],
    'available_place':montpellier[i]['-av']})

# %%
tmp
# Out:
# [{'name': '001 Rue Jules Ferry - Gare Saint-Roch',
#   'lat': '43.605366',
#   'lon': '3.881346',
#   'available_place': '1'},
#  {'name': '002 Comédie',
#   'lat': '43.608148',
#   'lon': '3.878778',
#   'available_place': '18'},
#  {'name': '003 Esplanade',
#   'lat': '43.609478',
#   'lon': '3.881293',
#   'available_place': '8'},
#  {'name': '004 Hôtel de Ville',
#   'lat': '43.599088',
#   'lon': '3.894866',
#   'available_place': '12'},
#  {'name': '005 Corum',
#   'lat': '43.613989',
#   'lon': '3.881600',
#   'available_place': '10'},
#  {'name': '006 Place Albert 1er - St Charles',
#   'lat': '43.616768',
#   'lon': '3.873375',
#   'available_place': '19'},
#  {'name': '007 Foch',
#   'lat': '43.610989',
#   'lon': '3.873345',
#   'available_place': '1'},
#  {'name': '008 Halles Castellane',
#   'lat': '43.609935',
#   'lon': '3.877208',
#   'available_place': '3'},
#  {'name': '009 Observatoire',
#   'lat': '43.606081',
#   'lon': '3.876931',
#   'available_place': '5'},
# ...

# %%
rennes[0]['fields']['nom']
# Out:
# 'Musée Beaux-Arts'

# %%
rennes = requests.get('https://data.rennesmetropole.fr/api/records/1.0/search/?dataset=etat-des-stations-le-velo-star-en-temps-reel')
rennes = rennes.json()
rennes = rennes['records']
tmp = []
for i in range(len(rennes)):
    tmp.append({'name': rennes[i]['fields']['nom'],
                'lat':rennes[i]['fields']['coordonnees'][0],
               'lon':rennes[i]['fields']['coordonnees'][1],
              'available_place':rennes[i]['fields']['nombrevelosdisponibles']})

# %%
tmp
# Out:
# [{'name': 'Musée Beaux-Arts',
#   'lat': 48.109601,
#   'lon': -1.67408,
#   'available_place': 10},
#  {'name': 'Plaine de Baud',
#   'lat': 48.112461,
#   'lon': -1.643674,
#   'available_place': 5},
#  {'name': 'Brest - Verdun',
#   'lat': 48.113009,
#   'lon': -1.693264,
#   'available_place': 15},
#  {'name': 'Marbeuf',
#   'lat': 48.111749,
#   'lon': -1.702077,
#   'available_place': 16},
#  {'name': 'Gros-Chêne',
#   'lat': 48.125408,
#   'lon': -1.664806,
#   'available_place': 5},
#  {'name': 'Painlevé',
#   'lat': 48.123506,
#   'lon': -1.659762,
#   'available_place': 0},
#  {'name': 'Joliot-Curie - Chateaubriand',
#   'lat': 48.124389,
#   'lon': -1.651203,
#   'available_place': 0},
#  {'name': 'Pont de Strasbourg',
#   'lat': 48.109859,
#   'lon': -1.656028,
#   'available_place': 19},
#  {'name': 'Mabilais',
#   'lat': 48.105086,
#   'lon': -1.693069,
#   'available_place': 13},
#  {'name': 'Champs Libres',
#   'lat': 48.105537,
#   'lon': -1.674328,
# ...

# %%
import rdflib
g = rdflib.Graph()
g.parse('station/rennes.rdf')
# Out:
# <Graph identifier=Ne35ce8167b314d689f3be41969029573 (<class 'rdflib.graph.Graph'>)>

# %%
[i for i in g]
# Out:
# [(rdflib.term.BNode('Nf6a9e50993e44c77b135306c34c7723b'),
#   rdflib.term.URIRef('http://www.owl-ontologies.com/unnamed.owlName'),
#   rdflib.term.Literal('Brest - Verdun', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))),
#  (rdflib.term.BNode('N6f153febf1a8449993432d11c99621f8'),
#   rdflib.term.URIRef('http://www.owl-ontologies.com/unnamed.owlcoordonnees'),
#   rdflib.term.Literal('-1.693069', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))),
#  (rdflib.term.BNode('Nb59279fc2de84b069399db8aedef1c49'),
#   rdflib.term.URIRef('http://www.owl-ontologies.com/unnamed.owlcoordonnees'),
#   rdflib.term.Literal('-1.674328', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))),
#  (rdflib.term.BNode('N44710835963b42ccb960265790e19227'),
#   rdflib.term.URIRef('http://www.owl-ontologies.com/unnamed.owlName'),
# ...

# %%
knows_query = """
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?name ?lat
WHERE{
    # ?subject <http://www.owl-ontologies.com/unnamed.owlName> ?name .
    # ?subject <http://www.owl-ontologies.com/unnamed.owllatitude> ?lat .
}
"""

# %%
qres = result.query(knows_query)
qres

# %%
for row in g.query(knows_query):
    print(row['name'])
